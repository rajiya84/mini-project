# %%
print("welcome to the simple Quiz maker!")

chances = 1
print("you will have",chances,"chance to answer correctly.\nplease put the alphabet of the answer\n")

score = 0
import random


question=print("1) what is membership operators?\n(a) in\n(b) or\n(c) is\n\n")
answer_1= "a"

for i in range(chances):
    answer=input("answer: ")
    if(answer.lower()==answer_1):
        print("correct!")
        score =score+1
        break
    else:
        print("incorrect!")
        print("the correct answer is",answer_1,"\n\n")

question=print("2) who developed the python?\n(a) zim den\n(b) Guido van Rossum\n(c) Niene Stom\n\n")
answer_2 = "b"

for i in range(chances):
    answer=input("answer: ")
    if(answer.lower()==answer_2):
        print("correct!")
        score =score+1
        break
    else:
        print("incorrect!")
        print("the correct answer is",answer_2,"\n\n")

question=print("3) what do we use to define a block of code in python language?\n(a) key\n(b) brackets\n(c) identation\n\n")
answer_3= "c"

for i in range(chances):
    answer=input("answer: ")
    if(answer.lower()==answer_3):
        print("correct!")
        score =score+1
        break
    else:
        print("incorrect!")
        print("the correct answer is",answer_3,"\n\n")
        
question=print("4) what is the method inside the class in python langauge\n(a) object\n(b) attributr\n(c) function\n\n")
answer_4 = "c"

for i in range(chances):
    answer=input("answer: ")
    if(answer.lower()==answer_4):
        print("correct!")
        score = score+1
        break
    else:
        print("incorrect!")
        print("the correct answer is",answer_4,"\n\n")

question=print("5) who is immutable data type?\n(a) int\n(b) dict\n(c) set\n\n")
answer_5 = "a"

for i in range(chances):
    answer=input("answer: ")
    if(answer.lower()==answer_5):
        print("correct!")
        score=score+1
        break
    else:
        print("incorrect!")
        print("the correct answer is",answer_5,"\n\n")
                
while score >=3:
    print("well done! your score is:",score,"/5")
    break 
while score <=2:
    print("Try again! your score is:",score,"/5")
    break
print("thank you!")
# Out:
# welcome to the simple Quiz maker!
# you will have 1 chance to answer correctly.
# please put the alphabet of the answer
#
# 1) what is membership operators?
# (a) in
# (b) or
# (c) is
#
#
# answer: a
# correct!
# 2) who developed the python?
# (a) zim den
# (b) Guido van Rossum
# (c) Niene Stom
#
#
# answer: b
# correct!
# 3) what do we use to define a block of code in python language?
# (a) key
# (b) brackets
# (c) identation
#
#
# answer: c
# correct!
# 4) what is the method inside the class in python langauge
# (a) object
# (b) attributr
# (c) function
#
#
# answer: c
# correct!
# 5) who is immutable data type?
# (a) int
# (b) dict
# (c) set
#
#
# answer: a
# correct!
# well done! your score is: 5 /5
# thank you!
